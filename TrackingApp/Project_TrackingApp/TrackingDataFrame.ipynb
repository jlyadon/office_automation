# %%
import pandas as pd

# %%
tracking_df = pd.read_csv('TrackingList.csv',dtype={'Client Nos.':str})
tracking_df.dtypes
# Out:
# Tracking Nos.    object
# Client Nos.      object
# Comments         object
# dtype: object

# %%
tracking_df.head(44)
# Out:
#              Tracking Nos. Client Nos.                              Comments
# 0     70191640000164106422    38525.02       4868 and check payment; Stack 1
# 1     70192280000060192481    48755.02       4868 and check payment; Stack 1
# 2   9114902200789659810412    23126.02                               Stack 1
# 3   9114902200789659710238    02541.02                  Source Docs; Stack 1
# 4   9114902200789659810320    94890.02                               Stack 1
# 5   9114902200789659810290    23126.02                               Stack 1
# 6   9114902200789659810306    25519.02                               Stack 1
# 7   9114902200852116737802    00442.02                               Stack 1
# 8   9114901230803154971622    21965.02                               Stack 1
# 9   9114902200852453171765    28948.02                               Stack 1
# 10    70211970000045308191    8104.201       Notice Form 706; Here before me
# ...
