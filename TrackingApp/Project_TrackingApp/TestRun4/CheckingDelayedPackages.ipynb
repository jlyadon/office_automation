# %%
import pandas as pd
df = pd.read_csv('TrackingList.csv')

# %%
targets_df = df[df.index > 100]
targets_df
# Out:
#               Tracking Nos.  Client Nos.                              Comments
# 101  9589071052701128330908    80901.020             Response to Letter CP162A
# 102  9589071052701128330625    63769.020                              Form 709
# 103    70211970000045303011     4522.200                          Notice CP161
# 104  9589071052701128330472     5844.020                    LA-ES June Payment
# 105  9589071052701128330489     5842.020                    LA-ES June Payment
# 106  9589071052701128330182    12710.020                      1040ES Voucher 2
# 107  9114902200852144849157    55583.020                           Source Docs
# 108  9114902200852144849201    46961.020                           Source Docs
# 109  9114902200852144849188    63768.020                           Source Docs
# 110  9114902200852144849263    14300.020                           Source Docs
# 111  9114902200852144849454    62878.020                           Two Returns
# 112  9114902200852144849454    19010.020                           Two Returns
# 113  9114902200852144849478    90797.020                             Form 1040
# 114    70211970000045302830    48685.020   Copies of 105C Letter and Form 2848
# 115  9589017052701128330984    28936.200                          2nd TFTR Ext
# 116  9589017052701128330977       65.205                          2nd TFTR Ext
# 117  9589071052701128331523    91205.020                          2nd TFTR Ext
# 118  9589071052701128331516    25106.020                  Revised 2nd TFTR Ext
# 119  9589071052701128331509     2785.020                          2nd TFTR Ext
# 120  9589071052701128331486    25106.020                          2nd TFTR Ext
# 121    70211970000045303103     5846.020                LA Tax Voucher Payment
# 122  9114901230803154974593    22358.020                           Source Docs
# 123  9114901230803154974647    62984.020                              Form 709
# 124  9114901230803154974630     7435.020                              Form 709
# 125  9114901230803154974654    17493.020                           Source Docs
# 126  9114901230803154974661    84406.020                           Source Docs
# 127  9114901230803154974678    88781.020                           Source Docs
# 128  9114901230803154974685    68883.020  Extra copy of CP2000 and Source Docs
# 129  9114901230803154974722    19210.020                           Source Docs
# 130  9114901230803154974739      504.020                             Form 1041
# 131    70211970000045309877    80398.020                          2nd TFTR Ext
# 132    70211970000045303134    82275.020             Form 3520A (put with Ext)
# 133  9114901230803154974746    92088.020                            Form 1120S
# 134  9114901230803154974746    92089.020                             Form 1065
# 135  9114901230803154974753     7603.020                           Source Docs
# 136  9114901230803154974753     7602.020                           Source Docs
# 137  9114901230803154974753     7604.020                           Source Docs
# 138  9114901230803154974760    83683.020             Form 1040 and Source Docs
# 139  9114901230803154974777     6265.020                           Source Docs

# %%
base_url = 'https://secure.shippingapis.com/ShippingAPI.dll?API=TrackV2&XML='
from config import userid, password

call_url = base_url + f'<TrackRequest USERID="{userid}" PASSWORD="{password}">'

batch_list = targets_df['Tracking Nos.']
for number in batch_list:
    call_url += f'<TrackID ID="{number}"></TrackID>'
call_url += '</TrackRequest>'

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get(call_url)
soup = BeautifulSoup(response.content, 'xml')

# %%
soup
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <TrackResponse><TrackInfo ID="9589071052701128330908"><TrackSummary>Your package is moving within the USPS network and is on track to be delivered to its final destination. It is currently in transit to the next facility.</TrackSummary><TrackDetail>In Transit to Next Facility, 07/05/2024</TrackDetail><TrackDetail>In Transit to Next Facility, 07/04/2024</TrackDetail><TrackDetail>Departed USPS Regional Facility, July 3, 2024, 9:58 pm, FORT WORTH TX DISTRIBUTION CENTER</TrackDetail><TrackDetail>Arrived at USPS Regional Origin Facility, 07/03/2024, 8:28 am, FORT WORTH TX DISTRIBUTION CENTER</TrackDetail><TrackDetail>Arrived at USPS Regional Origin Facility, 07/03/2024, 1:34 am, COPPELL TX DISTRIBUTION CENTER</TrackDetail><TrackDetail>USPS in possession of item, July 2, 2024, 10:58 am, WACO, TX 76710</TrackDetail></TrackInfo><TrackInfo ID="9589071052701128330625"><TrackSummary>Your package is moving within the USPS network and is on track to be delivered to its final destination. It is currently in transit to the next facility.</TrackSummary><TrackDetail>In Transit to Next Facility, 06/25/2024</TrackDetail><TrackDetail>In Transit to Next Facility, 06/24/2024</TrackDetail><TrackDetail>Arrived at USPS Regional Origin Facility, 06/22/2024, 12:46 am, COPPELL TX DISTRIBUTION CENTER</TrackDetail><TrackDetail>USPS in possession of item, June 21, 2024, 12:05 pm, WACO, TX 76710</TrackDetail></TrackInfo><TrackInfo ID="70211970000045303011"><TrackSummary>Your package is moving within the USPS network and is on track to be delivered to its final destination. It is currently in transit to the next facility.</TrackSummary><TrackDetail>In Transit to Next Facility, 06/26/2024</TrackDetail><TrackDetail>In Transit to Next Facility, 06/25/2024</TrackDetail><TrackDetail>In Transit to Next Facility, 06/24/2024</TrackDetail><TrackDetail>Arrived at USPS Regional Facility, June 23, 2024, 9:38 am, SALT LAKE CITY UT DISTRIBUTION CENTER</TrackDetail><TrackDetail>Arrived at USPS Regional Origin Facility, 06/21/2024, 1:29 am, COPPELL TX DISTRIBUTION CENTER</TrackDetail><TrackDetail>USPS in possession of item, June 20, 2024, 4:53 pm, WACO, TX 76710</TrackDetail></TrackInfo><TrackInfo ID="9589071052701128330472"><TrackSummary>Your package is moving within the USPS network and is on track to be delivered to its final destination. It is currently in transit to the next facility.</TrackSummary><TrackDetail>In Transit to Next Facility, 06/20/2024</TrackDetail><TrackDetail>Arrived at USPS Regional Facility, June 19, 2024, 10:38 am, BATON ROUGE LA PROCESSING CENTER</TrackDetail><TrackDetail>Arrived at USPS Regional Origin Facility, 06/18/2024, 12:04 am, COPPELL TX DISTRIBUTION CENTER</TrackDetail><TrackDetail>USPS in possession of item, June 17, 2024, 5:16 pm, WACO, TX 76710</TrackDetail></TrackInfo><TrackInfo ID="9589071052701128330489"><TrackSummary>Your package is moving within the USPS network and is on track to be delivered to its final destination. It is currently in transit to the next facility.</TrackSummary><TrackDetail>In Transit to Next Facility, 06/20/2024</TrackDetail><TrackDetail>Arrived at USPS Regional Facility, June 19, 2024, 10:38 am, BATON ROUGE LA PROCESSING CENTER</TrackDetail><TrackDetail>Arrived at USPS Regional Origin Facility, 06/18/2024, 12:04 am, COPPELL TX DISTRIBUTION CENTER</TrackDetail><TrackDetail>USPS in possession of item, June 17, 2024, 5:16 pm, WACO, TX 76710</TrackDetail></TrackInfo><TrackInfo ID="9589071052701128330182"><TrackSummary>Your package is moving within the USPS network and is on track to be delivered to its final destination. It is currently in transit to the next facility.</TrackSummary><TrackDetail>In Transit to Next Facility, 06/21/2024</TrackDetail><TrackDetail>Arrived at USPS Regional Facility, June 20, 2024, 10:50 am, CHARLOTTE NC DISTRIBUTION CENTER</TrackDetail><TrackDetail>In Transit to Next Facility, 06/19/2024</TrackDetail><TrackDetail>Arrived at USPS Regional Origin Facility, 06/18/2024, 12:04 am, COPPELL TX ...

# %%
string = str(soup)
string = string.replace('><','>\n<')
string = string.replace('</TrackInfo>','</TrackInfo>\n--\n')
string
# Out:
# '<?xml version="1.0" encoding="utf-8"?>\n<TrackResponse>\n<TrackInfo ID="9589071052701128330908">\n<TrackSummary>Your package is moving within the USPS network and is on track to be delivered to its final destination. It is currently in transit to the next facility.</TrackSummary>\n<TrackDetail>In Transit to Next Facility, 07/05/2024</TrackDetail>\n<TrackDetail>In Transit to Next Facility, 07/04/2024</TrackDetail>\n<TrackDetail>Departed USPS Regional Facility, July 3, 2024, 9:58 pm, FORT WORTH TX DISTRIBUTION CENTER</TrackDetail>\n<TrackDetail>Arrived at USPS Regional Origin Facility, 07/03/2024, 8:28 am, FORT WORTH TX DISTRIBUTION CENTER</TrackDetail>\n<TrackDetail>Arrived at USPS Regional Origin Facility, 07/03/2024, 1:34 am, COPPELL TX DISTRIBUTION CENTER</TrackDetail>\n<TrackDetail>USPS in possession of item, July 2, 2024, 10:58 am, WACO, TX 76710</TrackDetail>\n</TrackInfo>\n--\n\n<TrackInfo ID="9589071052701128330625">\n<TrackSummary>Your package is moving within the USPS network and is on track to be delivered to its final destination. It is currently in transit to the next facility.</TrackSummary>\n<TrackDetail>In Transit to Next Facility, 06/25/2024</TrackDetail>\n<TrackDetail>In Transit to Next Facility, 06/24/2024</TrackDetail>\n<TrackDetail>Arrived at USPS Regional Origin Facility, 06/22/2024, 12:46 am, COPPELL TX DISTRIBUTION CENTER</TrackDetail>\n<TrackDetail>USPS in possession of item, June 21, 2024, 12:05 pm, WACO, TX 76710</TrackDetail>\n</TrackInfo>\n--\n\n<TrackInfo ID="70211970000045303011">\n<TrackSummary>Your package is moving within the USPS network and is on track to be delivered to its final destination. It is currently in transit to the next facility.</TrackSummary>\n<TrackDetail>In Transit to Next Facility, 06/26/2024</TrackDetail>\n<TrackDetail>In Transit to Next Facility, 06/25/2024</TrackDetail>\n<TrackDetail>In Transit to Next Facility, 06/24/2024</TrackDetail>\n<TrackDetail>Arrived at USPS Regional Facility, June 23, 2024, 9:38 am, SALT LAKE CITY UT DISTRIBUTION CENTER</TrackDetail>\n<TrackDetail>Arrived at USPS Regional Origin Facility, 06/21/2024, 1:29 am, COPPELL TX DISTRIBUTION CENTER</TrackDetail>\n<TrackDetail>USPS in possession of item, June 20, 2024, 4:53 pm, WACO, TX 76710</TrackDetail>\n</TrackInfo>\n--\n\n<TrackInfo ID="9589071052701128330472">\n<TrackSummary>Your package is moving within the USPS network and is on track to be delivered to its final destination. It is currently in transit to the next facility.</TrackSummary>\n<TrackDetail>In Transit to Next Facility, 06/20/2024</TrackDetail>\n<TrackDetail>Arrived at USPS Regional Facility, June 19, 2024, 10:38 am, BATON ROUGE LA PROCESSING CENTER</TrackDetail>\n<TrackDetail>Arrived at USPS Regional Origin Facility, 06/18/2024, 12:04 am, COPPELL TX DISTRIBUTION CENTER</TrackDetail>\n<TrackDetail>USPS in possession of item, June 17, 2024, 5:16 pm, WACO, TX 76710</TrackDetail>\n</TrackInfo>\n--\n\n<TrackInfo ID="9589071052701128330489">\n<TrackSummary>Your package is moving within the USPS network and is on track to be delivered to its final destination. It is currently in transit to the next facility.</TrackSummary>\n<TrackDetail>In Transit to Next Facility, 06/20/2024</TrackDetail>\n<TrackDetail>Arrived at USPS Regional Facility, June 19, 2024, 10:38 am, BATON ROUGE LA PROCESSING CENTER</TrackDetail>\n<TrackDetail>Arrived at USPS Regional Origin Facility, 06/18/2024, 12:04 am, COPPELL TX DISTRIBUTION CENTER</TrackDetail>\n<TrackDetail>USPS in possession of item, June 17, 2024, 5:16 pm, WACO, TX 76710</TrackDetail>\n</TrackInfo>\n--\n\n<TrackInfo ID="9589071052701128330182">\n<TrackSummary>Your package is moving within the USPS network and is on track to be delivered to its final destination. It is currently in transit to the next facility.</TrackSummary>\n<TrackDetail>In Transit to Next Facility, 06/21/2024</TrackDetail>\n<TrackDetail>Arrived at USPS Regional Facility, June 20, 2024, 10:50 am, CHARLOTTE NC DISTRIBUTION CENTER</TrackDet ...

# %%
file = open('report.txt','a')
file.write(string)
file.close()
