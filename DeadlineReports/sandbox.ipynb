# %%
import pandas as pd
import xlsxwriter
filepath = r'.\09-30-2024\Macro_Playground_09-27_8-38.xlsx'
report_df = pd.read_excel(filepath)
report_df.head()
# Out:
#        Responsible Party  Awaiting Info  Awaiting Pickup  Awaiting Software  \
# 0             Ai, Yujuan            NaN              NaN                NaN
# 1        Beard, James M.            5.0              NaN                NaN
# 2       Berry, Connie S.            3.0              NaN                NaN
# 3       Bivona, Brian P.            NaN              NaN                NaN
# 4  Breitkreutz, Jared W.            4.0              NaN                NaN
#
#    Cleared 1st Review Points  Cleared Final Review Points  Final Review  \
# 0                        NaN                          NaN           NaN
# 1                        NaN                          NaN           NaN
# 2                        NaN                          NaN           2.0
# 3                        NaN                          NaN           NaN
# 4                        NaN                          NaN           NaN
#
# ...
